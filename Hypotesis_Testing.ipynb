# %% [markdown]
# # **Hypotesis Testing**

# %%
# Load data from Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The `Chi-square` test of independence tests if there is a **significant relationship** between **two categorical variables**.

# %%
# Load libraries
import pandas as pd
from scipy.stats import chi2_contingency

# %%
# Read data
path = "the-path-in-gdrive"
data = pd.read_csv(path)

# %%
# due created_at actually has timestamp value convert and sort dataframe according timestamp distribution from past to current
# Convert 'created_date' to datetime and extract the date
data['created_at_date'] = pd.to_datetime(data['created_at']).dt.date
data = data.sort_values(by = "created_at").reset_index(drop = True)

# %%
# Overview dataset
data
# Out:
#         transaction_id  user_id  amount payment_type           created_at  \
# 0               277040     7884   17143      balance  2023-07-03 07:00:14
# 1               131303     5098   25283         cash  2023-07-03 07:00:19
# 2               299267     6089   44640         cash  2023-07-03 07:00:21
# 3                75138     7125   30692      balance  2023-07-03 07:01:52
# 4               333300     5130   41472      balance  2023-07-03 07:02:29
# ...                ...      ...     ...          ...                  ...
# 437995           39130     6438   34176      balance  2024-07-03 06:56:09
# 437996          240500     7472   14521         cash  2024-07-03 06:57:00
# 437997           73832     7360   39802      balance  2024-07-03 06:57:32
# 437998           99775     5651   14367      balance  2024-07-03 06:58:53
# 437999          201627     5487   20662      balance  2024-07-03 06:59:45
#
#                  updated_at  deleted_at category_vendor_name  \
# 0       2023-07-03 07:31:51         NaN              makanan
# 1       2023-07-03 08:13:49         NaN                 jasa
# 2       2023-07-03 07:25:54         NaN    alat rumah tangga
# 3       2023-07-03 07:18:44         NaN           elektronik
# 4       2023-07-03 08:15:01         NaN              pakaian
# ...                     ...         ...                  ...
# 437995  2024-07-03 06:58:50         NaN    alat rumah tangga
# 437996  2024-07-03 08:45:29         NaN              pakaian
# 437997  2024-07-03 06:59:11         NaN              pakaian
# 437998  2024-07-03 07:34:10         NaN              makanan
# 437999  2024-07-03 07:17:55         NaN           elektronik
#
#                       vendor_name             jajan_item_name  \
# 0                Sambel Sejahtera           Ayam Goreng Kriuk
# 1       Creative Solutions Agency        Desain Grafis Kustom
# 2        Modern Living Appliances        Penghisap Debu Robot
# 3                  Inovasi Gadget  Headphone Wireless Premium
# 4        Trendy Footwear Boutique       Sepatu Sneakers Urban
# ...                           ...                         ...
# 437995   Home Essentials Emporium          Vakum Cleaner Kuat
# 437996          Tren Mode Terkini        Celana Denim Stylish
# 437997     Koleksi Fashion Elegan          Sepatu Boots Kulit
# 437998           Sambel Sejahtera           Ayam Goreng Kriuk
# 437999        Tech Gadgets Galore           Kamera Mirrorless
#
#                 country     sub_country        day  hour created_at_date
# 0         Jakarta Pusat       Kemayoran     Monday     7      2023-07-03
# 1       Jakarta Selatan        Pancoran     Monday     7      2023-07-03
# 2       Jakarta Selatan  Kebayoran Lama     Monday     7      2023-07-03
# 3         Jakarta Barat     Kebon Jeruk     Monday     7      2023-07-03
# 4         Jakarta Pusat       Kemayoran     Monday     7      2023-07-03
# ...                 ...             ...        ...   ...             ...
# 437995    Jakarta Pusat           Senen  Wednesday     6      2024-07-03
# 437996    Jakarta Barat        Palmerah  Wednesday     6      2024-07-03
# 437997    Jakarta Barat        Palmerah  Wednesday     6      2024-07-03
# 437998    Jakarta Pusat           Senen  Wednesday     6      2024-07-03
# 437999    Jakarta Pusat       Kemayoran  Wednesday     6      2024-07-03
#
# [438000 rows x 15 columns]

# %%
# Group by 'created_at_date' and 'day', and count the transactions for each day
daily_transactions = data.groupby(['created_at_date', 'day']).size().reset_index(name='total_transactions')

# %%
# Overview new dataframe
daily_transactions
# Out:
#     created_at_date        day  total_transactions
# 0        2023-07-03     Monday                 891
# 1        2023-07-04    Tuesday                1145
# 2        2023-07-05  Wednesday                1162
# 3        2023-07-06   Thursday                1208
# 4        2023-07-07     Friday                1255
# ..              ...        ...                 ...
# 362      2024-06-29   Saturday                1178
# 363      2024-06-30     Sunday                1214
# 364      2024-07-01     Monday                1243
# 365      2024-07-02    Tuesday                1190
# 366      2024-07-03  Wednesday                 341
#
# [367 rows x 3 columns]

# %%
# Create a pivot table with 'day' as columns, 'created_at_date' as index, and 'total_transactions' as values
pivot_table = daily_transactions.pivot(index='created_at_date', columns='day', values='total_transactions')

# %%
# Overview pivot_table
pivot_table
# Out:
# day              Friday  Monday  Saturday  Sunday  Thursday  Tuesday  \
# created_at_date
# 2023-07-03          NaN   891.0       NaN     NaN       NaN      NaN
# 2023-07-04          NaN     NaN       NaN     NaN       NaN   1145.0
# 2023-07-05          NaN     NaN       NaN     NaN       NaN      NaN
# 2023-07-06          NaN     NaN       NaN     NaN    1208.0      NaN
# 2023-07-07       1255.0     NaN       NaN     NaN       NaN      NaN
# ...                 ...     ...       ...     ...       ...      ...
# 2024-06-29          NaN     NaN    1178.0     NaN       NaN      NaN
# 2024-06-30          NaN     NaN       NaN  1214.0       NaN      NaN
# 2024-07-01          NaN  1243.0       NaN     NaN       NaN      NaN
# 2024-07-02          NaN     NaN       NaN     NaN       NaN   1190.0
# 2024-07-03          NaN     NaN       NaN     NaN       NaN      NaN
#
# day              Wednesday
# created_at_date
# 2023-07-03             NaN
# 2023-07-04             NaN
# 2023-07-05          1162.0
# 2023-07-06             NaN
# 2023-07-07             NaN
# ...                    ...
# 2024-06-29             NaN
# 2024-06-30             NaN
# 2024-07-01             NaN
# 2024-07-02             NaN
# 2024-07-03           341.0
#
# [367 rows x 7 columns]

# %% [markdown]
# Null Hypothesis (H0): **There is no relationship between the day of the week and the total daily transactions.**
#
# Alternative Hypothesis (H1): **There is a relationship between the day of the week and the total daily transactions.**
#
# The `p-value` is the **probability** that you would have found the current result if the **null hypothesis were true**. If the p-value is less than 0.05, we reject the null hypothesis.

# %%
# Perform Chi-Square test of independence
chi2, p, dof, expected = chi2_contingency(pivot_table.fillna(0))

# %%
print(f"Chi-square: {chi2}")
print(f"P-value: {p}")
# Out:
# Chi-square: 2628000.0
# P-value: 0.0

# %% [markdown]
#  In this case, the Chi-square value is quite large, which suggests a **significant difference**.
#
# p-value of 0.0 leads us to reject the null hypothesis. This means **there is a statistically significant relationship between the day of the week and the total daily transactions**.
#
# In other words, the total daily transactions are dependent on what day of the week it is.
